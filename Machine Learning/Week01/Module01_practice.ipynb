# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset
df = sns.load_dataset('penguins')

# %% [markdown]
# # Task 01

# %%
print("number of rows:",df.shape[0])
print("number of columns:",df.shape[1])
# Out:
# number of rows: 344
# number of columns: 7

# %%
df.head(7)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female

# %%
df.sample(5)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 285     Gentoo     Biscoe            49.8           16.8              230.0
# 337     Gentoo     Biscoe            48.8           16.2              222.0
# 167  Chinstrap      Dream            50.5           19.6              201.0
# 79      Adelie  Torgersen            42.1           19.1              195.0
# 143     Adelie      Dream            40.7           17.0              190.0
#
#      body_mass_g   sex
# 285       5700.0  Male
# 337       6000.0  Male
# 167       4050.0  Male
# 79        4000.0  Male
# 143       3725.0  Male

# %% [markdown]
# Why might it be better to look at a random sample rather than just the top rows?
# - It might be better because sometimes the 1st rows are sorted based on any feature(column), and then we will see some specific data for df.head(). But randomness solves this.
# - sometimes null values or garbage values are not present in first rows. we can discover them when randomly accessed.

# %% [markdown]
# # Task 02

# %%
print(df.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# sex contains highest num of missing values

# %% [markdown]
# # Task 03

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Task 04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # Task 05

# %%
sns.countplot(x='species', data=df)
plt.title('Count of Each Penguin Species')
# Out:
# Text(0.5, 1.0, 'Count of Each Penguin Species')

# %% [markdown]
# # Task 07

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sex_value = df['sex'].value_counts()
print(sex_value)
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.pie(sex_value.values, labels=sex_value.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1cc4cafea20>,
# ...
#  [Text(-0.6950710323057664, -0.85257038422021, 'Male'),
#   Text(0.6950711610403049, 0.8525702792673944, 'Female')],
#  [Text(-0.37912965398496346, -0.46503839139284175, '50.5%'),
#   Text(0.3791297242038026, 0.46503833414585144, '49.5%')])
