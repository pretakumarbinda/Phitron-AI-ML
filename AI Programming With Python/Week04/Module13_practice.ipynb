# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Practice.csv')
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89

# %% [markdown]
# # Problem 01

# %%
modified_df = df['Discounted_Price'] = df['Price'] - (df['Price']*0.1)
modified_df.to_csv('discounted_products.csv', index=False)

# %% [markdown]
# # Problem 02

# %%
df['EmployeeID'].duplicated().sum()
dropped_dup = df.drop_duplicates(subset=['EmployeeID'])

dropped_dup
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %% [markdown]
# # Problem 03

# %%
print(df["Age"].isnull().sum())
print(df["Salary"].isnull().sum())

df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Salary"] = df["Salary"].dropna()
# Out:
# 0
# 0

# %% [markdown]
# # Problem 04

# %%
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 3            1080.0
# 4            2250.0

# %%
print(df["Marks1"].mean())
print(df["Marks2"].mean())
print(df["Marks3"].mean())

print(df["Marks1"].max())
print(df["Marks2"].max())
print(df["Marks3"].max())
# Out:
# 85.22222222222223
# 87.33333333333333
# 86.88888888888889
# 95
# 95

# %%
total_marks = df['Marks1'] + df['Marks2'] + df['Marks3']
print(total_marks)
# Out:
# 0     263
# 1     240
# 2     277
# 3     263
# 4     262
# 5     236
# 6     273
# 9     281
# 10    240
# dtype: int64

# %%
total_marks.std()
# Out:
# np.float64(16.934514394507385)

# %% [markdown]
# # Problem 05

# %%
plt.hist(df["Age"])
# Out:
# (array([1., 3., 0., 4., 0., 0., 0., 0., 0., 1.]),
#  array([22. , 24.3, 26.6, 28.9, 31.2, 33.5, 35.8, 38.1, 40.4, 42.7, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df["Age"], df["Salary"])

# %%
plt.scatter(df["Price"], df["Discounted_Price"])

# %% [markdown]
# # Problem 05

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1Sy7rA0G9gTmeItVZ-XlugkKF4CPPqvxU')
df.head()
# Out:
#    Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0       13.5         2.0            17.7        72
# 1        8.0        18.0             5.0        75
# 2        6.4         7.2            22.7        78
# 3        6.9         8.7             6.6       110
# 4       10.5         8.6             5.8       104

# %%
plt.scatter(df["Study_Hour"], df["IQ_Score"])
plt.xlabel("Study Hours")
plt.ylabel("IQ Score")
# Out:
# Text(0, 0.5, 'IQ Score')
